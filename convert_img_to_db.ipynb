# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#
# make readable txt report of dates for fileobjects in a dfxml file
import os
import argparse
import sys
import re

#import Objects.py from python dfxml tools
#sys.path.append('/Users/sunflower/PHD/python')
#sys.path.append(os.path.join(os.path.dirname(__file__), ".."))
#import dfxml
import dfxml.objects as objects2

#import objects2

dfxml_path = "/Users/seunfuta/Downloads/M57/charlie-2009-12-11.xml"
img_path = "/Users/seunfuta/Downloads/M57/charlie-2009-12-11.raw.raw"
allocated = False
num_files = int()
num_files == 0
mtimes = []
crtimes = []
atimes = []

# gather info for each FileObject
for (event, obj) in objects2.iterparse( dfxml_path ):
    #Only work on FileObjects
    if not isinstance(obj, objects2.FileObject):
        continue
    
    #If allocated argument passed, skip unallocated files
    if allocated == True:
        if obj.alloc == 0:
            continue
    
    # gather info

    #ByteRunx = obj.data_brs()
    #ByteRunc = dfxmlobjects.ByteRuns()
    #for attr, value in ByteRunx().__dict__.iteritems():
        #print attr, value
    #print ("Byteruns", ByteRunx._listdata)

    #app = args.app
    filemd5 = obj.md5
    filepath = obj.filename
    filesize = obj.filesize
    byte_runs = obj.byte_runs
    print("filemd5", filemd5, "filepath", filepath,"filesize", filesize, "byte_runs", type(byte_runs))
    if filemd5:# and not re.search(r'\.$',filepath):
        num_files += 1
        #print("app", app, "filemd5", filemd5, "filepath", filepath, "filesize", filesize, "byte_runs", type(byte_runs))
        #for runs in obj.byte_runs.__iter__():
        #    print("runs", runs)
        print("filemd5", filemd5, "filepath", filepath,"filesize", filesize, "byte_runs", type(byte_runs))
    '''
    cluster_hash = []

    mtime = obj.mtime
    if not mtime:
        mtime = ''
    mtime = str(mtime)
    mtimes.append(mtime)

    crtime = obj.crtime
    if not crtime:
        crtime = obj.ctime # account for "ctime" in md5deep-created DFXML
    if not crtime:
        crtime = ''
    crtime = str(crtime)
    crtimes.append(crtime)

    atime = obj.atime
    if not atime:
        atime = ''
    atime = str(atime)
    atimes.append(atime)

    fname = obj.filename
    fsize = obj.filesize
    fsize = str(fsize)
    alloc = obj.alloc # 1 = allocated file
    '''

# print aggregate info
print('\n\nSTATS')
print('-----')

print('Number of files: ' + str(num_files))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/s7/d__51l693s13d_yt81j0qp9r0000gn/T/ipykernel_39203/3259649879.py in <module>
#      26
#      27 # gather info for each FileObject
# ---> 28 for (event, obj) in objects2.iterparse( dfxml_path ):
#      29     #Only work on FileObjects
#      30     if not isinstance(obj, objects2.FileObject):
#
# ~/Downloads/paper2research/dfxml/objects.py in iterparse(filename, events, **kwargs)
#    4847
#    4848     parser = Parser()
# -> 4849     for (event, obj) in parser.iterparse(fh, _events, **kwargs):
#    4850         yield (event, obj)
#    4851
#
# ~/Downloads/paper2research/dfxml/objects.py in iterparse(self, fh, events, **kwargs)
#    4567                     for eop in self.transition(Parser.VOLUME_PRESTREAM): yield eop
#    4568                 elif ln == "fileobject":
# -> 4569                     for eop in self.transition(Parser._FILE_START): yield eop
#    4570                     # All other work happens at the fileobject's end event.
#    4571                 else:
#
# ~/Downloads/paper2research/dfxml/objects.py in transition(self, to_state)
#    4683
#    4684         if not to_state in Parser.transitions[self.state]:
# -> 4685             raise ValueError("DFXML stream has unexpected state transition: %r -> %r." % (self.state, to_state))
#    4686         from_state = self.state
#    4687         self.state = to_state
#
# ValueError: DFXML stream has unexpected state transition: 500 -> 500.

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# make readable txt report of dates for fileobjects in a dfxml file
import os
import argparse
import sys
import re
import pandas as pd
import hashlib
# import Objects.py from python dfxml tools
#sys.path.append('/Users/sunflower/PHD/python')
#sys.path.append(os.path.join(os.path.dirname(__file__), ".."))
import dfxml
import dfxml.objects as objects2
# import objects2
json_path =  "/Users/seunfuta/Downloads/M57/charlie-2009-12-11.json"
img_path =  "/Users/seunfuta/Downloads/M57/charlie-2009-12-11.raw.raw"
dfxml_path =  "/Users/seunfuta/Downloads/M57/charlie-2009-12-11.xml"

num_files = int()
num_files = 0
out_json = open(json_path, 'w')
with open(img_path, 'rb') as img_h:
    # gather info for each FileObject
    filestr_list = []
    for (event, obj) in objects2.iterparse(dfxml_path):
        # Only work on FileObjects
        if not isinstance(obj, objects2.FileObject):
            continue

        #app = args.app
        filemd5 = obj.md5
        filepath = obj.filename
        filesize = obj.filesize
        byte_runs = obj.byte_runs
        if filemd5 and not re.search(r'\.$', filepath):
            num_files += 1
            #{"file_hash": "54aa35cbe9d1fb383cbc33e1879b210e","file_type": "","filesize": 45966800,"name_pairs": ["Chrome28-W7x64","Users/user/AppData/Local/Google/Chrome/Application/28.0.1500.95/chrome.dll"],"nonprobative_count": 9800,"zero_count": 779}
            filestr = "{\"file_hash\": \"" + filemd5+ "\",\"file_type\": \"\",\"filesize\":"+str(filesize)+",\"name_pairs\": [\"app\",\""+filepath+"\"],\"nonprobative_count\": 0,\"zero_count\": 0}"
            if filestr not in filestr_list: filestr_list.append(filestr)
            # print("app", app, "filemd5", filemd5, "filepath", filepath, "filesize", filesize, "byte_runs", type(byte_runs))
            for runs in obj.byte_runs.__iter__():
                print("runs", runs.img_offset, runs.len, runs.file_offset, runs.fs_offset)
                if runs.img_offset and runs.len:
                    img_h.seek(runs.img_offset)
                    block_hash=""
                    for block in range(0,int(float(runs.len)/float(512))+1):
                        block_hash = hashlib.md5(img_h.read(512)).hexdigest()
                        strx = "{\"block_hash\":\""+block_hash+"\",\"img_offset\":"+str(int(runs.img_offset)+int(int(block) * int(512)))+",\"source_sub_counts\":[\""+filemd5+"\",1,["+str(int(runs.file_offset+(512*block)))+"]],\"block_label\":\"XX\"}"
                #print("filemd5", filemd5, "filepath", filepath, "filesize", filesize, "byte_runs",byte_runs, type(byte_runs.__iter__()), type(byte_runs.__repr__()))
                        print(strx)
                        out_json.write(strx)
                        out_json.write("\n")
                else:
                    continue
    for filestr in filestr_list:
        print(filestr)
        out_json.write(filestr)
        out_json.write("\n")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/s7/d__51l693s13d_yt81j0qp9r0000gn/T/ipykernel_39203/1090777911.py in <module>
#      25     # gather info for each FileObject
#      26     filestr_list = []
# ---> 27     for (event, obj) in objects2.iterparse(dfxml_path):
#      28         # Only work on FileObjects
#      29         if not isinstance(obj, objects2.FileObject):
#
# ~/Downloads/paper2research/dfxml/objects.py in iterparse(filename, events, **kwargs)
#    4847
#    4848     parser = Parser()
# -> 4849     for (event, obj) in parser.iterparse(fh, _events, **kwargs):
#    4850         yield (event, obj)
#    4851
#
# ~/Downloads/paper2research/dfxml/objects.py in iterparse(self, fh, events, **kwargs)
#    4567                     for eop in self.transition(Parser.VOLUME_PRESTREAM): yield eop
#    4568                 elif ln == "fileobject":
# -> 4569                     for eop in self.transition(Parser._FILE_START): yield eop
#    4570                     # All other work happens at the fileobject's end event.
#    4571                 else:
#
# ~/Downloads/paper2research/dfxml/objects.py in transition(self, to_state)
#    4683
#    4684         if not to_state in Parser.transitions[self.state]:
# -> 4685             raise ValueError("DFXML stream has unexpected state transition: %r -> %r." % (self.state, to_state))
#    4686         from_state = self.state
#    4687         self.state = to_state
#
# ValueError: DFXML stream has unexpected state transition: 500 -> 500.

# %%
import dfxml.fiwalk as fiwalk
import dfxml 

import sys

imagefile = open("/Users/seunfuta/Downloads/M57/charlie-2009-12-11.raw.raw")
data = ""
def process(fi): # fi=fileobject
    #offset = fi.contents().find(data)
    #if offset>0:
    print(fi.filename())
    
objs = fiwalk.fileobjects_using_sax(imagefile=imagefile)
print(type(objs))
for i in range(1):
    print(objs[i].partition())
# Out:
# <class 'list'>
# 1

# %%
from pprint import pprint
for i in range(206,207):
   byte_rlist = []       
   for ebyterun in objs[i].byte_runs():
      print(ebyterun.img_offset,ebyterun.file_offset, ebyterun.len, ebyterun.fs_offset , ebyterun.__dict__ )
   byte_rrun = objs[i].byte_runs()
   print("filename",objs[i].filename())
   print("ext", objs[i].ext())
   print("filesize", objs[i].filesize())
   print( "fragments", objs[i].fragments())
   print("byteruns()",objs[i].byte_runs())
   print("byteruns",objs[i].byte_runs)
   print("byterunlist", byte_rlist)
   print("inode", objs[i].inode())
   print( "is_file",objs[i].is_file())
   print("fragments",objs[i].fragments())
   print(objs[i].__dict__)
   pprint(vars(objs[i]))
   print(dir(objs[i]))
# Out:
# 27868672 0 6197 27836416 {'img_offset': 27868672, 'file_offset': 0, 'len': 6197, 'sector_size': 512, 'hashdigest': {}, 'fs_offset': 27836416}
# filename Documents and Settings/Administrator/Application Data/OpenOffice.org/3/user/registry/cache/org.openoffice.Office.Linguistic.dat
# ext dat
# filesize 6197
# fragments 1
# byteruns() [<dfxml.byte_run object at 0x7f8f46dd1f40>]
# byteruns <bound method fileobject_sax.byte_runs of <dfxml.fileobject_sax object at 0x7f8f46dd1ee0>>
# byterunlist []
# inode 22743
# is_file True
# fragments 1
# {'imagefile': <_io.TextIOWrapper name='/Users/seunfuta/Downloads/M57/charlie-2009-12-11.raw.raw' mode='r' encoding='UTF-8'>, 'hashdigest': {'md5': 'a5f1b0831dc5312a5278dd416e113182', 'sha1': '9b5cfd6d0a50a70d89c1289c24cdf2eb73cfbac1'}, '_tags': {'inode': '22743', 'parent_object': None, 'filename': 'Documents and Settings/Administrator/Application Data/OpenOffice.org/3/user/registry/cache/org.openoffice.Office.Linguistic.dat', 'partition': '1', 'id': '207', 'name_type': 'r', 'filesize': '6197', 'alloc': '1', 'used': '1', 'meta_type': '1', 'mode': '511', 'nlink': '2', 'uid': '0', 'gid': '0', 'mtime': '2009-11-10T01:22:22Z', 'ctime': '2009-11-10T01:22:22Z', 'atime': '2009-11-10T01:22:22Z', 'crtime': '2009-11-10T01:22:22Z', 'seq': '2', 'byte_run': '', 'byte_runs': None, 'md5': 'a5f1b0831dc5312a5278dd416e113182', 'sha1': '9b5cfd6d0a50a70d89c1289c24cdf2eb73cfbac1'}, '_byte_runs': [<dfxml.byte_run object at 0x7f8f46dd1f40>], 'volume': <dfxml.volumeobject_sax object at 0x7f8f454a9370>}
# {'_byte_runs': [<dfxml.byte_run object at 0x7f8f46dd1f40>],
#  '_tags': {'alloc': '1',
#            'atime': '2009-11-10T01:22:22Z',
#            'byte_run': '',
#            'byte_runs': None,
#            'crtime': '2009-11-10T01:22:22Z',
#            'ctime': '2009-11-10T01:22:22Z',
#            'filename': 'Documents and Settings/Administrator/Application '
#                        'Data/OpenOffice.org/3/user/registry/cache/org.openoffice.Office.Linguistic.dat',
#            'filesize': '6197',
#            'gid': '0',
#            'id': '207',
#            'inode': '22743',
#            'md5': 'a5f1b0831dc5312a5278dd416e113182',
#            'meta_type': '1',
#            'mode': '511',
#            'mtime': '2009-11-10T01:22:22Z',
#            'name_type': 'r',
#            'nlink': '2',
#            'parent_object': None,
#            'partition': '1',
#            'seq': '2',
#            'sha1': '9b5cfd6d0a50a70d89c1289c24cdf2eb73cfbac1',
#            'uid': '0',
#            'used': '1'},
#  'hashdigest': {'md5': 'a5f1b0831dc5312a5278dd416e113182',
#                 'sha1': '9b5cfd6d0a50a70d89c1289c24cdf2eb73cfbac1'},
#  'imagefile': <_io.TextIOWrapper name='/Users/seunfuta/Downloads/M57/charlie-2009-12-11.raw.raw' mode='r' encoding='UTF-8'>,
#  'volume': <dfxml.volumeobject_sax object at 0x7f8f454a9370>}
# ['TIMETAGLIST', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_byte_runs', '_tags', 'allocated', 'allocated_inode', 'allocated_name', 'atime', 'byte_runs', 'compressed', 'content_for_run', 'contents', 'crtime', 'ctime', 'dtime', 'encrypted', 'ext', 'file_present', 'filename', 'filesize', 'frag_start_sector', 'fragments', 'gid', 'has_contents', 'has_sector', 'has_tag', 'hashdigest', 'imagefile', 'inode', 'is_dir', 'is_file', 'is_virtual', 'libmagic', 'md5', 'meta_type', 'mode', 'mtime', 'name_type', 'partition', 'savefile', 'sha1', 'sha256', 'tag', 'tempfile', 'times', 'uid', 'volume']

# %%
from pprint import pprint
counter = 0
print(len(objs))
for obj in objs:
    if obj.is_file() == True and obj.filesize() > 1000000 :# and obj.filesize() == False:
        counter += 1
        byterun = []
        for ebyterun in obj.byte_runs():
            #print(ebyterun.img_offset,ebyterun.file_offset, ebyterun.len, ebyterun.fs_offset )
            byterun.append([ebyterun.file_offset, ebyterun.len])
            if ebyterun.img_offset: byterun.append(ebyterun.img_offset)
            if ebyterun.fs_offset: byterun.append(ebyterun.fs_offset)
        pprint(vars(ebyterun))
        print( "inode:",obj.inode(), "partition:",obj.partition(), "name_type:",\
            obj.name_type(),"id:",obj._tags['id'], "filename:",obj.filename(), "filesize:", obj.filesize() , \
                "fragments", obj.fragments(), "img_offset:file_offset:len:fs_offset",byterun)
        break
print(counter)
# Out:
# 40065
# {'file_offset': 1384448,
#  'fs_offset': 7064100864,
#  'hashdigest': {},
#  'img_offset': 7064133120,
#  'len': 46319,
#  'sector_size': 512}
# inode: 23106 partition: 1 name_type: r id: 380 filename: Documents and Settings/Administrator/Application Data/Sun/Java/Deployment/cache/6.0/21/14e5d595-2f810799 filesize: 1430767 fragments 18 img_offset:file_offset:len:fs_offset [[0, 8192], 4693175808, 4693143552, [8192, 16384], 5480427008, 5480394752, [24576, 24576], 7102582272, 7102550016, [49152, 49152], 7143869952, 7143837696, [98304, 176128], 7270972928, 7270940672, [274432, 53248], 7185194496, 7185162240, [327680, 69632], 841428480, 841396224, [397312, 126976], 7246568960, 7246536704, [524288, 69632], 855821824, 855789568, [593920, 61440], 836845056, 836812800, [655360, 131072], 4849294848, 4849262592, [786432, 69632], 857611776, 857579520, [856064, 126976], 7269756416, 7269724160, [983040, 69632], 864194048, 864161792, [1052672, 61440], 832384512, 832352256, [1114112, 180224], 7336488448, 7336456192, [1294336, 90112], 7095176704, 7095144448, [1384448, 46319], 7064133120, 7064100864]
# 1

# %%
#Lets make sure all "files" are covered
# Lets store it a DB
import pandas as pd
import sqlite3

cols = ['obj_id', 'partition','inode','filename','filesize']
file_df = pd.DataFrame(columns=cols)

from pprint import pprint
counter = 0
print(len(objs))
for obj in objs:
    if obj.is_file() == True and obj.filesize() > 1000000 :# and obj.filesize() == False:
        counter += 1
        byterun = []
        for ebyterun in obj.byte_runs():
            #print(ebyterun.img_offset,ebyterun.file_offset, ebyterun.len, ebyterun.fs_offset )
            if int(obj._tags['id']) > 6584: 
                pprint(vars(ebyterun)) 
                print(obj.filename(), "obj_id", obj._tags['id'], "partition",obj.partition(),"inode", obj.inode(),"filesize",  obj.filesize())
            byterun.append([ebyterun.img_offset,ebyterun.file_offset, ebyterun.len, ebyterun.fs_offset])
            #byterun.append([ebyterun.file_offset, ebyterun.len])
            #if hasattr(ebyterun,'img_offset'): byterun.append(ebyterun.img_offset)
            #if hasattr(ebyterun,'fs_offset'): byterun.append(ebyterun.fs_offset)
        #pprint(vars(ebyterun))
        #print( "inode:",obj.inode(), "partition:",obj.partition(), "name_type:",\
            #obj.name_type(),"id:",obj._tags['id'], "filename:",obj.filename(), "filesize:", obj.filesize() , \
                #"fragments", obj.fragments(), "img_offset:file_offset:len:fs_offset",byterun)
        data = [obj._tags['id'], obj.partition(),obj.inode(), obj.filename(),  obj.filesize()]
        print("data",data)
        #file_df.loc[len(file_df.index)]= data
        #break
print(counter)
#print(len(file_df))
# Out:
# 40065
# data ['380', '1', '23106', 'Documents and Settings/Administrator/Application Data/Sun/Java/Deployment/cache/6.0/21/14e5d595-2f810799', 1430767]
# data ['412', '1', '23114', 'Documents and Settings/Administrator/Application Data/Sun/Java/Deployment/cache/6.0/27/20d3eedb-5b5c4d14', 8763090]
# data ['572', '1', '17265', 'Documents and Settings/Administrator/Application Data/Sun/Java/jre1.6.0_16/Data1.cab', 13005452]
# data ['573', '1', '17392', 'Documents and Settings/Administrator/Application Data/Sun/Java/jre1.6.0_16/jre1.6.0_16.msi', 1757696]
# data ['610', '1', '17310', 'Documents and Settings/Administrator/Desktop/OpenOffice.org 3.1 (en-US) Installation Files/instmsia.exe', 1708856]
# data ['611', '1', '17292', 'Documents and Settings/Administrator/Desktop/OpenOffice.org 3.1 (en-US) Installation Files/instmsiw.exe', 1822520]
# data ['615', '1', '17338', 'Documents and Settings/Administrator/Desktop/OpenOffice.org 3.1 (en-US) Installation Files/java/jre-windows-i586.exe', 16664352]
# data ['621', '1', '17289', 'Documents and Settings/Administrator/Desktop/OpenOffice.org 3.1 (en-US) Installation Files/openofficeorg1.cab', 135630545]
# data ['622', '1', '17317', 'Documents and Settings/Administrator/Desktop/OpenOffice.org 3.1 (en-US) Installation Files/openofficeorg31.msi', 9815040]
# data ['631', '1', '17333', 'Documents and Settings/Administrator/Desktop/OpenOffice.org 3.1 (en-US) Installation Files/redist/vcredist_x86.exe', 1821192]
# data ['666', '1', '11161', 'Documents and Settings/Administrator/Local Settings/Application Data/IconCache.db', 2684182]
# data ['783', '1', '22884', 'Documents and Settings/Administrator/Local Settings/Temp/a8c81.mst', 5199360]
# data ['813', '1', '11185', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/avgdm90_pro_0700_027.pack', 1107292]
# data ['829', '1', '11590', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/12/avgidpsdkx.dll', 2516248]
# data ['830', '1', '11572', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/12/AVGIDSAgent.exe', 5832712]
# data ['839', '1', '11584', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/12/RegistryCoverage.xml', 1171062]
# data ['856', '1', '11614', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/13/internalList.zip', 2192880]
# data ['891', '1', '11788', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/27/avgdiagex.exe', 3293976]
# data ['906', '1', '11815', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/33/avgchsvx.exe', 1055000]
# data ['916', '1', '11554', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/36/avgfws9.exe', 2321720]
# data ['917', '1', '11555', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/36/avgfwui.dll', 2661144]
# data ['918', '1', '11556', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/36/avgfwwiz.dll', 1959192]
# data ['939', '1', '11494', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/5/avgspmui.dll', 1191704]
# data ['941', '1', '11496', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/5/winspamcatcher.dll', 5460392]
# data ['969', '1', '11742', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/64/avgrsa.exe', 1057048]
# data ['976', '1', '11210', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avgabout.dll', 1207064]
# data ['978', '1', '11275', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avgapix.dll', 1946392]
# data ['983', '1', '11363', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avgcmgr.exe', 1074456]
# data ['986', '1', '11209', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avgfrw.exe', 1257752]
# data ['991', '1', '11371', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avglvea.dll', 1497880]
# data ['998', '1', '11211', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avgresf.dll', 2352920]
# data ['1005', '1', '11314', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avgssff.dll', 1336600]
# data ['1006', '1', '11319', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avgssie.dll', 1471768]
# data ['1007', '1', '11321', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avgssiea.dll', 2114840]
# data ['1010', '1', '11212', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avgtray.exe', 2010904]
# data ['1011', '1', '11213', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avgui.exe', 4015384]
# data ['1031', '1', '11240', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/setup.dat', 2266133]
# data ['1032', '1', '11241', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/setup.exe', 3774232]
# data ['1077', '1', '11377', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/vcredist.msi', 2736128]
# data ['1082', '1', '11215', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avguires.dll', 3499288]
# data ['1083', '1', '11272', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avgupd.dll', 1657112]
# data ['1086', '1', '11306', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avgwd.dll', 1494088]
# data ['1089', '1', '11365', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avgxpl.dll', 1082648]
# data ['1090', '1', '11372', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avgxpla.dll', 1449752]
# data ['1091', '1', '11379', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avi7.avg', 6061540]
# data ['1103', '1', '11312', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/dbghelp.dll', 1045128]
# data ['1111', '1', '11382', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/incavi.avm', 44820047]
# data ['1116', '1', '11214', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/avguiadv.dll', 2421016]
# data ['1147', '1', '11373', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/65/crt_x64.msi', 1648128]
# data ['1158', '1', '11547', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/9/avgcorex.dll', 3963672]
# data ['1163', '1', '11172', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/avgdm90_pro_0700_009.pack', 1674626]
# data ['1165', '1', '11174', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/avgdm90_pro_0700_012.pack', 2912829]
# data ['1166', '1', '11175', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/avgdm90_pro_0700_013.pack', 2222659]
# data ['1177', '1', '11186', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/avgdm90_pro_0700_028.pack', 1020856]
# data ['1183', '1', '11196', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/avgdm90_pro_0700_036.pack', 1623300]
# data ['1185', '1', '11198', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/avgdm90_pro_0700_057.pack', 1397656]
# data ['1186', '1', '11199', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/avgdm90_pro_0700_060.pack', 1336545]
# data ['1190', '1', '11202', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/avgdm90_pro_0700_065.pack', 19286342]
# data ['1193', '1', '11203', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/u7avi1760aq.bin', 6629093]
# data ['1194', '1', '11204', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/u7iavi2490ut.bin', 45077014]
# data ['1199', '1', '11168', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/avgdm90_pro_0700_005.pack', 1681107]
# data ['1210', '1', '11045', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/update/avgstubres.dll', 3196184]
# data ['1212', '1', '11046', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/update/stub.exe', 1021208]
# data ['1214', '1', '11383', 'Documents and Settings/Administrator/Local Settings/Temp/Davg9inst_2009-11-09_01-38.log', 8247298]
# data ['1545', '1', '17404', 'Documents and Settings/Administrator/Local Settings/Temporary Internet Files/Content.IE5/HIS1Z5A9/OOo_3.1.1_Win32Intel_install_wJRE_en-US[1].exe', 157484384]
# data ['1638', '1', '10846', 'Documents and Settings/Administrator/Local Settings/Temporary Internet Files/Content.IE5/HIS1Z5A9/R79733[1].EXE', 4255056]
# data ['1917', '1', '29400', 'Documents and Settings/All Users/Application Data/Apple/Installer Cache/Apple Software Update 2.1.1.116/AppleSoftwareUpdate.msi', 2083840]
# data ['1921', '1', '29485', 'Documents and Settings/All Users/Application Data/Apple/Installer Cache/AppleApplicationSupport 1.1.0/AppleApplicationSupport.msi', 11535872]
# data ['1931', '1', '29862', 'Documents and Settings/All Users/Application Data/Apple Computer/Installer Cache/QuickTime 7.65.17.80/QuickTime.msi', 28214272]
# data ['2137', '1', '15768', 'Documents and Settings/All Users/Application Data/avg9/Antispam/sc18.bin.tmp2', 2843268]
# data ['2289', '1', '11947', 'Documents and Settings/All Users/Application Data/avg9/CfgAll/fw.cfg', 2900906]
# data ['2298', '1', '29252', 'Documents and Settings/All Users/Application Data/avg9/Chjw/cm-2-p.dat', 1777016]
# data ['2348', '1', '11618', 'Documents and Settings/All Users/Application Data/avg9/IDS/Config/RegistryCoverage.xml', 1171062]
# data ['2353', '1', '11612', 'Documents and Settings/All Users/Application Data/avg9/IDS/Config/internalList.zip', 2352551]
# data ['2354', '1', '15867', 'Documents and Settings/All Users/Application Data/avg9/IDS/Config/internalList.zip.bak', 2352551]
# data ['2489', '1', '12903', 'Documents and Settings/All Users/Application Data/avg9/Log/avgchjw.log.1', 1024310]
# data ['2490', '1', '11939', 'Documents and Settings/All Users/Application Data/avg9/Log/avgchjw.log.2', 1024018]
# data ['2495', '1', '13325', 'Documents and Settings/All Users/Application Data/avg9/Log/avgcore.log.1', 1024142]
# data ['2496', '1', '10599', 'Documents and Settings/All Users/Application Data/avg9/Log/avgcore.log.2', 1024332]
# data ['2497', '1', '12267', 'Documents and Settings/All Users/Application Data/avg9/Log/avgcore.log.3', 1024104]
# data ['2498', '1', '28897', 'Documents and Settings/All Users/Application Data/avg9/Log/avgcore.log.4', 1024318]
# data ['2499', '1', '24034', 'Documents and Settings/All Users/Application Data/avg9/Log/avgcore.log.5', 1025496]
# data ['2500', '1', '11900', 'Documents and Settings/All Users/Application Data/avg9/Log/avgcore.log.6', 1024002]
# data ['2540', '1', '11909', 'Documents and Settings/All Users/Application Data/avg9/Log/avgns.log.1', 1024144]
# data ['2543', '1', '11937', 'Documents and Settings/All Users/Application Data/avg9/Log/avgrs.log.1', 1025108]
# data ['2562', '1', '31505', 'Documents and Settings/All Users/Application Data/avg9/Log/avgupd.log', 1461634]
# data ['2563', '1', '11966', 'Documents and Settings/All Users/Application Data/avg9/Log/avgupd.log.1', 10240182]
# data ['2595', '1', '2558', 'Documents and Settings/All Users/Application Data/avg9/Log/avgsched.log.1', 1024020]
# data ['2596', '1', '4962', 'Documents and Settings/All Users/Application Data/avg9/Log/avgsched.log.10', 1024030]
# data ['2597', '1', '2740', 'Documents and Settings/All Users/Application Data/avg9/Log/avgsched.log.2', 1024142]
# data ['2598', '1', '11458', 'Documents and Settings/All Users/Application Data/avg9/Log/avgsched.log.3', 1024184]
# data ['2599', '1', '10542', 'Documents and Settings/All Users/Application Data/avg9/Log/avgsched.log.4', 1024300]
# data ['2600', '1', '10585', 'Documents and Settings/All Users/Application Data/avg9/Log/avgsched.log.5', 1024110]
# data ['2601', '1', '10533', 'Documents and Settings/All Users/Application Data/avg9/Log/avgsched.log.6', 1024210]
# data ['2602', '1', '9896', 'Documents and Settings/All Users/Application Data/avg9/Log/avgsched.log.7', 1024202]
# data ['2603', '1', '9895', 'Documents and Settings/All Users/Application Data/avg9/Log/avgsched.log.8', 1024080]
# data ['2604', '1', '9342', 'Documents and Settings/All Users/Application Data/avg9/Log/avgsched.log.9', 1024000]
# data ['2611', '1', '10055', 'Documents and Settings/All Users/Application Data/avg9/Log/avgwd.log.1', 1024196]
# data ['2612', '1', '4940', 'Documents and Settings/All Users/Application Data/avg9/Log/avgwd.log.10', 1024242]
# data ['2613', '1', '9949', 'Documents and Settings/All Users/Application Data/avg9/Log/avgwd.log.2', 1024036]
# data ['2614', '1', '3094', 'Documents and Settings/All Users/Application Data/avg9/Log/avgwd.log.3', 1024234]
# data ['2615', '1', '10602', 'Documents and Settings/All Users/Application Data/avg9/Log/avgwd.log.4', 1024024]
# data ['2616', '1', '9914', 'Documents and Settings/All Users/Application Data/avg9/Log/avgwd.log.5', 1024080]
# data ['2617', '1', '7545', 'Documents and Settings/All Users/Application Data/avg9/Log/avgwd.log.6', 1024326]
# data ['2618', '1', '6823', 'Documents and Settings/All Users/Application Data/avg9/Log/avgwd.log.7', 1024190]
# data ['2619', '1', '7710', 'Documents and Settings/All Users/Application Data/avg9/Log/avgwd.log.8', 1024360]
# data ['2620', '1', '5533', 'Documents and Settings/All Users/Application Data/avg9/Log/avgwd.log.9', 1024184]
# data ['2709', '1', '24017', 'Documents and Settings/All Users/Application Data/avg9/update/backup/avgcorex.dll', 3963648]
# data ['2710', '1', '24019', 'Documents and Settings/All Users/Application Data/avg9/update/backup/avgfrw.exe', 1257240]
# data ['2715', '1', '24020', 'Documents and Settings/All Users/Application Data/avg9/update/backup/avgtray.exe', 2016536]
# data ['2716', '1', '24021', 'Documents and Settings/All Users/Application Data/avg9/update/backup/avgui.exe', 4026136]
# data ['2717', '1', '15803', 'Documents and Settings/All Users/Application Data/avg9/update/backup/avgupd.dll', 1658136]
# data ['2721', '1', '15795', 'Documents and Settings/All Users/Application Data/avg9/update/backup/incavi.avm', 46359526]
# data ['2723', '1', '15783', 'Documents and Settings/All Users/Application Data/avg9/update/backup/internalList.dat', 4892288]
# data ['2755', '1', '15817', 'Documents and Settings/All Users/Application Data/avg9/update/download/w9ui703b697nm.bin', 1040340]
# data ['2759', '1', '12489', 'Documents and Settings/All Users/Application Data/avg9/update/download/w9upd708uk.bin', 1952616]
# data ['3386', '1', '28292', 'Documents and Settings/Charlie/Application Data/Microsoft/Internet Explorer/Internet Explorer Wallpaper.bmp', 6313854]
# data ['3848', '1', '23765', 'Documents and Settings/Charlie/Application Data/Sun/Java/Deployment/cache/6.0/21/14e5d595-44888f42', 1430767]
# data ['3880', '1', '23773', 'Documents and Settings/Charlie/Application Data/Sun/Java/Deployment/cache/6.0/27/20d3eedb-644004ba', 8763090]
# data ['4134', '1', '28983', 'Documents and Settings/Charlie/Application Data/Thunderbird/Profiles/4zy34x9h.default/extensions/{e2fda1a4-762b-4020-b5ad-a41df1933103}/chrome/calendar.jar', 2212136]
# data ['4223', '1', '27978', 'Documents and Settings/Charlie/Application Data/Thunderbird/Profiles/4zy34x9h.default/Mail/Local Folders/Inbox', 1582329]
# data ['4226', '1', '23512', 'Documents and Settings/Charlie/Application Data/Thunderbird/Profiles/4zy34x9h.default/Mail/Local Folders/Sent', 1357460]
# data ['4303', '1', '28353', 'Documents and Settings/Charlie/Desktop/web/urlspatents.txt', 5374418]
# data ['4305', '1', '28354', 'Documents and Settings/Charlie/Desktop/web/urlstime_machine.txt', 1538835]
# data ['4349', '1', '23456', 'Documents and Settings/Charlie/Local Settings/Application Data/IconCache.db', 4295178]
# data ['4647', '1', '12634', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/7F34EDB1d01', 7341564]
# data ['4768', '1', '24438', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/3EA79371d01', 6873872]
# data ['4796', '1', '29354', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/736CD417d01', 1291720]
# data ['5058', '1', '29379', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/BD08133Ed01', 32494896]
# data ['5063', '1', '32556', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/BD37BD7Dd01', 2062398]
# data ['5080', '1', '31112', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/E3E47FA8d01', 3225964]
# data ['5292', '1', '29077', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/642D63FEd01', 1925560]
# data ['5410', '1', '32550', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/B877AD1Dd01', 1391864]
# data ['5590', '1', '24489', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/07946B4Cd01', 14890496]
# data ['5670', '1', '11832', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/DD85320Bd01', 1479430]
# data ['5862', '1', '32393', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/35C672E2d01', 1964484]
# data ['5910', '1', '28374', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/46E1C49Fd01', 5313992]
# data ['5942', '1', '32546', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/708797BBd01', 1130124]
# data ['6037', '1', '12501', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/FFD98676d01', 1899851]
# data ['6039', '1', '24360', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/_CACHE_001_', 5924512]
# data ['6040', '1', '24361', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/_CACHE_002_', 5277088]
# data ['6041', '1', '24362', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/_CACHE_003_', 14095948]
# data ['6129', '1', '28569', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/Cache/3AF6B56Dd01', 1282928]
# data ['6157', '1', '24366', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/urlclassifier3.sqlite', 41517056]
# data ['6158', '1', '24337', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/XPC.mfl', 2281396]
# data ['6159', '1', '24346', 'Documents and Settings/Charlie/Local Settings/Application Data/Mozilla/Firefox/Profiles/2usvf7i1.default/XUL.mfl', 1552263]
# data ['6178', '1', '24448', 'Documents and Settings/Charlie/Local Settings/Application Data/Thunderbird/Profiles/4zy34x9h.default/XPC.mfl', 1187688]
# data ['6179', '1', '28927', 'Documents and Settings/Charlie/Local Settings/Application Data/Thunderbird/Profiles/4zy34x9h.default/XUL.mfl', 3493432]
# data ['6231', '1', '29076', 'Documents and Settings/Charlie/Local Settings/Temp/FP_PL_PFS_INSTALLER.exe', 1925560]
# data ['6427', '1', '24211', 'Documents and Settings/Charlie/Local Settings/Temporary Internet Files/Content.IE5/G5MBG5U7/Firefox%20Setup%203.5.5[1].exe', 8084968]
# data ['6550', '1', '28373', 'Documents and Settings/Charlie/My Documents/Downloads/FoxitReader31_enu_Setup_1030.exe', 5313992]
# data ['6551', '1', '28925', 'Documents and Settings/Charlie/My Documents/Downloads/lightning-0.9-tb-win.xpi', 2144261]
# data ['6552', '1', '28566', 'Documents and Settings/Charlie/My Documents/Downloads/MNspreadsheetTagged.csv', 1282928]
# data ['6554', '1', '24485', 'Documents and Settings/Charlie/My Documents/Downloads/python-2.6.4.msi', 14890496]
# data ['6555', '1', '24437', 'Documents and Settings/Charlie/My Documents/Downloads/Thunderbird Setup 2.0.0.23.exe', 6873872]
# data ['6580', '1', '32545', 'Documents and Settings/Charlie/My Documents/Quantum Cryptography/09145392.zip', 1130124]
# data ['6583', '1', '28310', 'Documents and Settings/Charlie/My Documents/Quantum Cryptography/B877AD1Dd01.pdf', 1391864]
# data ['6584', '1', '32562', 'Documents and Settings/Charlie/My Documents/Quantum Cryptography/BD37BD7Dd01.pdf', 2062398]
# {'file_offset': 0,
#  'fs_offset': 8560496640,
#  'hashdigest': {},
#  'img_offset': 8560528896,
#  'len': 933888,
#  'sector_size': 512}
# Documents and Settings/Charlie/NTUSER.DAT obj_id 6593 partition 1 inode 23259 filesize 1048576
# {'file_offset': 933888,
#  'fill': 0,
#  'hashdigest': {},
#  'img_offset': None,
#  'len': 114688,
#  'sector_size': 512}
# Documents and Settings/Charlie/NTUSER.DAT obj_id 6593 partition 1 inode 23259 filesize 1048576
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/s7/d__51l693s13d_yt81j0qp9r0000gn/T/ipykernel_39203/3569624460.py in <module>
#      19                 pprint(vars(ebyterun))
#      20                 print(obj.filename(), "obj_id", obj._tags['id'], "partition",obj.partition(),"inode", obj.inode(),"filesize",  obj.filesize())
# ---> 21             byterun.append([ebyterun.img_offset,ebyterun.file_offset, ebyterun.len, ebyterun.fs_offset])
#      22             #byterun.append([ebyterun.file_offset, ebyterun.len])
#      23             #if hasattr(ebyterun,'img_offset'): byterun.append(ebyterun.img_offset)
#
# AttributeError: 'byte_run' object has no attribute 'fs_offset'

# %%
id = 969
#Lets make sure all "files" are covered
# Lets store it a DB
import pandas as pd
import sqlite3

cols = ['obj_id', 'partition','inode','filename','filesize']
file_df = pd.DataFrame(columns=cols)

from pprint import pprint
counter = 0
print(len(objs))
for obj in objs:
    if int(obj._tags['id']) == id:# and obj.filesize() == False:
        counter += 1
        byterun = []
        for ebyterun in obj.byte_runs():
            #print(ebyterun.img_offset,ebyterun.file_offset, ebyterun.len, ebyterun.fs_offset )
            #if int(obj._tags['id']) == id: 
            pprint(vars(ebyterun)) 
            print(obj.filename(), "obj_id", obj._tags['id'], "partition",obj.partition(),"inode", obj.inode(),"filesize",  obj.filesize())
            byterun.append([ebyterun.img_offset,ebyterun.file_offset, ebyterun.len, ebyterun.fs_offset])
            #byterun.append([ebyterun.file_offset, ebyterun.len])
            #if hasattr(ebyterun,'img_offset'): byterun.append(ebyterun.img_offset)
            #if hasattr(ebyterun,'fs_offset'): byterun.append(ebyterun.fs_offset)
        #pprint(vars(ebyterun))
        #print( "inode:",obj.inode(), "partition:",obj.partition(), "name_type:",\
            #obj.name_type(),"id:",obj._tags['id'], "filename:",obj.filename(), "filesize:", obj.filesize() , \
                #"fragments", obj.fragments(), "img_offset:file_offset:len:fs_offset",byterun)
        data = [obj._tags['id'], obj.partition(),obj.inode(), obj.filename(),  obj.filesize()]
        print("data",data)
        #file_df.loc[len(file_df.index)] = data
        break
print(counter)
#print(len(file_df))
# Out:
# 40065
# {'file_offset': 0,
#  'fs_offset': 5205811200,
#  'hashdigest': {},
#  'img_offset': 5205843456,
#  'len': 1057048,
#  'sector_size': 512}
# Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/64/avgrsa.exe obj_id 969 partition 1 inode 11742 filesize 1057048
# data ['969', '1', '11742', 'Documents and Settings/Administrator/Local Settings/Temp/AVGDownloadManager/packages/64/avgrsa.exe', 1057048]
# 1

# %%
with open(imagefile, 'rb') as img_h:   # dict[dfxml]
    #first cluster
    ##cluster_file_offset = int(fileoffset)
    ##clust_img_pos = int(image_offset) + int(fileoffset)
    ##fopen.seek(clust_img_pos)
    ##fsector = fopen.read(4096)
    ##cluster_hash = hashlib.md5(fsector).hexdigest()
    ##csv_writer.writerow([0, cluster_file_offset, cluster_file_offset + 4096, sys.argv[5], filehash, filepath, filesize, cluster_hash])

    #second to second-to-last cluster
    for btye in 
    for sector_index in range(int(fileoffset), int(fileoffset)+int(leng), 4096):
        block_meta_dict = {}
        clust_img_pos = int(image_offset) + sector_index
        cluster_file_offset = sector_index
        m_fileoffset = int(fileoffset) + sector_index
        fopen.seek(clust_img_pos)
        fsector = fopen.read(4096)
        cluster_hash = hashlib.md5(fsector).hexdigest()
        csv_writer.writerow([cluster_file_offset,sys.argv[5],filehash, filepath, filesize, cluster_hash])

# %%
#id = 380
#Lets make sure all "files" are covered
# Lets store it a DB
import pandas as pd
import sqlite3
import hashlib
import pprint
conn = sqlite3.connect("/Users/seunfuta/Downloads/M57/charlie-2009-12-11.db")
cur = conn.cursor()
cur.execute('CREATE TABLE IF NOT EXISTS files (obj_id INTEGER, partition INTEGER, inode INTEGER, filename TEXT, filesize INTEGER)')
conn.commit()
cur.execute('CREATE TABLE IF NOT EXISTS block_hashes (obj_id INTEGER, img_offset INTEGER,fs_offset INTEGER, file_offset INTEGER,len INTEGER, md5 TEXT,sha1 TEXT)')
conn.commit()

img_path =  "/Users/seunfuta/Downloads/M57/charlie-2009-12-11.raw.raw"
files_cols = ['obj_id', 'partition','inode','filename','filesize']
block_hashes_cols = ['obj_id','img_offset','fs_offset','file_offset','len','md5','sha1']
file_df = pd.DataFrame(columns=files_cols)
block_hashes_df = pd.DataFrame(columns=block_hashes_cols)

sector_size = 512
from pprint import pprint
counter = 0
print(len(objs))
with open(img_path, 'rb') as img_h:
    for obj in objs:
        #if int(obj._tags['id']) == id:# and obj.filesize() == False:
        counter += 1
        #print(obj.filename())
        data = [obj._tags['id'], obj.partition(),obj.inode(), obj.filename(),  obj.filesize()]
        file_df.loc[len(file_df.index)] = data
        #print(data)
        byterun = []
        persist_img_offset = 0
        persist_fs_offset = 0
        persist_file_offset = 0
        for ebyterun in obj.byte_runs():
            #pprint(vars(ebyterun)) 
            #byterun.append([ebyterun.img_offset,ebyterun.file_offset, ebyterun.len, ebyterun.fs_offset])
            byterun.append(ebyterun.file_offset)
            persist_file_offset = ebyterun.file_offset
            byterun.append(ebyterun.len)
            if hasattr(ebyterun,'img_offset'): 
                byterun.append(ebyterun.img_offset)
                if ebyterun.img_offset != None: persist_img_offset = ebyterun.img_offset
            if hasattr(ebyterun,'fs_offset'): 
                byterun.append(ebyterun.fs_offset)
                if ebyterun.fs_offset != None: persist_fs_offset = ebyterun.fs_offset
            #print("img_offset", img_offset, "file offset", ebyterun.file_offset)
            #print("file_offset", "len", "img_offset", "fs_offset")
            #print(byterun)
            
            remaining_len = ebyterun.len
            #cur_file_offset = 0
            #print("image offset", persist_img_offset)
            #print("file offset", ebyterun.file_offset)
            #print("len", ebyterun.len)
            #print()
            for pointer in range(persist_img_offset,persist_img_offset+ebyterun.len, sector_size):
                #print(pointer)
                persist_img_offset = pointer
                
                img_h.seek(pointer)
                fsector = img_h.read(sector_size)
                
                hash_len = min(remaining_len,sector_size)
                
                sector_md5 = hashlib.md5(fsector).hexdigest()
                sector_sha1 = hashlib.sha1(fsector).hexdigest()
                data2 = [obj._tags['id'], pointer, persist_fs_offset, persist_file_offset, hash_len, sector_md5, sector_sha1]
                persist_fs_offset+=sector_size 
                persist_file_offset+=sector_size 
                remaining_len -= sector_size
                block_hashes_df.loc[len(block_hashes_df.index)] = data2

        print(counter, " out of ", len(objs), "id= ",obj._tags['id'])

    #print(len(file_df))
file_df.to_sql('files', conn, if_exists='replace', index = False)
block_hashes_df.to_sql('block_hashes', conn, if_exists='replace', index = False)
conn.close()
# Out:
# 40065
# 1  out of  40065 id=  1
# 2  out of  40065 id=  2
# 3  out of  40065 id=  3
# 4  out of  40065 id=  4
# 5  out of  40065 id=  5
# 6  out of  40065 id=  6
# 7  out of  40065 id=  7
# 8  out of  40065 id=  8
# 9  out of  40065 id=  9
# 10  out of  40065 id=  10
# 11  out of  40065 id=  11
# 12  out of  40065 id=  12
# 13  out of  40065 id=  13
# 14  out of  40065 id=  14
# 15  out of  40065 id=  15
# 16  out of  40065 id=  16
# 17  out of  40065 id=  17
# 18  out of  40065 id=  18
# 19  out of  40065 id=  19
# 20  out of  40065 id=  20
# 21  out of  40065 id=  21
# 22  out of  40065 id=  22
# 23  out of  40065 id=  23
# 24  out of  40065 id=  24
# 25  out of  40065 id=  25
# 26  out of  40065 id=  26
# 27  out of  40065 id=  27
# 28  out of  40065 id=  28
# 29  out of  40065 id=  29
# 30  out of  40065 id=  30
# 31  out of  40065 id=  31
# 32  out of  40065 id=  32
# 33  out of  40065 id=  33
# 34  out of  40065 id=  34
# 35  out of  40065 id=  35
# 36  out of  40065 id=  36
# 37  out of  40065 id=  37
# 38  out of  40065 id=  38
# 39  out of  40065 id=  39
# 40  out of  40065 id=  40
# 41  out of  40065 id=  41
# 42  out of  40065 id=  42
# 43  out of  40065 id=  43
# 44  out of  40065 id=  44
# 45  out of  40065 id=  45
# 46  out of  40065 id=  46
# 47  out of  40065 id=  47
# 48  out of  40065 id=  48
# 49  out of  40065 id=  49
# 50  out of  40065 id=  50
# 51  out of  40065 id=  51
# 52  out of  40065 id=  52
# 53  out of  40065 id=  53
# 54  out of  40065 id=  54
# 55  out of  40065 id=  55
# 56  out of  40065 id=  56
# 57  out of  40065 id=  57
# 58  out of  40065 id=  58
# 59  out of  40065 id=  59
# 60  out of  40065 id=  60
# 61  out of  40065 id=  61
# 62  out of  40065 id=  62
# 63  out of  40065 id=  63
# 64  out of  40065 id=  64
# 65  out of  40065 id=  65
# 66  out of  40065 id=  66
# 67  out of  40065 id=  67
# 68  out of  40065 id=  68
# 69  out of  40065 id=  69
# 70  out of  40065 id=  70
# 71  out of  40065 id=  71
# 72  out of  40065 id=  72
# 73  out of  40065 id=  73
# 74  out of  40065 id=  74
# 75  out of  40065 id=  75
# 76  out of  40065 id=  76
# 77  out of  40065 id=  77
# 78  out of  40065 id=  78
# 79  out of  40065 id=  79
# 80  out of  40065 id=  80
# 81  out of  40065 id=  81
# 82  out of  40065 id=  82
# 83  out of  40065 id=  83
# 84  out of  40065 id=  84
# 85  out of  40065 id=  85
# 86  out of  40065 id=  86
# 87  out of  40065 id=  87
# 88  out of  40065 id=  88
# 89  out of  40065 id=  89
# 90  out of  40065 id=  90
# 91  out of  40065 id=  91
# 92  out of  40065 id=  92
# 93  out of  40065 id=  93
# 94  out of  40065 id=  94
# 95  out of  40065 id=  95
# 96  out of  40065 id=  96
# 97  out of  40065 id=  97
# 98  out of  40065 id=  98
# 99  out of  40065 id=  99
# 100  out of  40065 id=  100
# 101  out of  40065 id=  101
# 102  out of  40065 id=  102
# 103  out of  40065 id=  103
# 104  out of  40065 id=  104
# 105  out of  40065 id=  105
# 106  out of  40065 id=  106
# 107  out of  40065 id=  107
# 108  out of  40065 id=  108
# 109  out of  40065 id=  109
# 110  out of  40065 id=  110
# 111  out of  40065 id=  111
# 112  out of  40065 id=  112
# 113  out of  40065 id=  113
# 114  out of  40065 id=  114
# 115  out of  40065 id=  115
# 116  out of  40065 id=  116
# 117  out of  40065 id=  117
# 118  out of  40065 id=  118
# 119  out of  40065 id=  119
# 120  out of  40065 id=  120
# 121  out of  40065 id=  121
# 122  out of  40065 id=  122
# 123  out of  40065 id=  123
# 124  out of  40065 id=  124
# 125  out of  40065 id=  125
# 126  out of  40065 id=  126
# 127  out of  40065 id=  127
# 128  out of  40065 id=  128
# 129  out of  40065 id=  129
# 130  out of  40065 id=  130
# 131  out of  40065 id=  131
# 132  out of  40065 id=  132
# 133  out of  40065 id=  133
# 134  out of  40065 id=  134
# 135  out of  40065 id=  135
# 136  out of  40065 id=  136
# 137  out of  40065 id=  137
# 138  out of  40065 id=  138
# 139  out of  40065 id=  139
# 140  out of  40065 id=  140
# 141  out of  40065 id=  141
# 142  out of  40065 id=  142
# 143  out of  40065 id=  143
# 144  out of  40065 id=  144
# 145  out of  40065 id=  145
# 146  out of  40065 id=  146
# 147  out of  40065 id=  147
# 148  out of  40065 id=  148
# 149  out of  40065 id=  149
# 150  out of  40065 id=  150
# 151  out of  40065 id=  151
# 152  out of  40065 id=  152
# 153  out of  40065 id=  153
# 154  out of  40065 id=  154
# 155  out of  40065 id=  155
# 156  out of  40065 id=  156
# 157  out of  40065 id=  157
# 158  out of  40065 id=  158
# 159  out of  40065 id=  159
# 160  out of  40065 id=  160
# 161  out of  40065 id=  161
# 162  out of  40065 id=  162
# 163  out of  40065 id=  163
# 164  out of  40065 id=  164
# 165  out of  40065 id=  165
# 166  out of  40065 id=  166
# 167  out of  40065 id=  167
# 168  out of  40065 id=  168
# 169  out of  40065 id=  169
# 170  out of  40065 id=  170
# 171  out of  40065 id=  171
# 172  out of  40065 id=  172
# 173  out of  40065 id=  173
# 174  out of  40065 id=  174
# 175  out of  40065 id=  175
# 176  out of  40065 id=  176
# 177  out of  40065 id=  177
# 178  out of  40065 id=  178
# 179  out of  40065 id=  179
# 180  out of  40065 id=  180
# 181  out of  40065 id=  181
# 182  out of  40065 id=  182
# 183  out of  40065 id=  183
# 184  out of  40065 id=  184
# 185  out of  40065 id=  185
# 186  out of  40065 id=  186
# 187  out of  40065 id=  187
# 188  out of  40065 id=  188
# 189  out of  40065 id=  189
# 190  out of  40065 id=  190
# 191  out of  40065 id=  191
# 192  out of  40065 id=  192
# 193  out of  40065 id=  193
# 194  out of  40065 id=  194
# 195  out of  40065 id=  195
# 196  out of  40065 id=  196
# 197  out of  40065 id=  197
# 198  out of  40065 id=  198
# 199  out of  40065 id=  199
# 200  out of  40065 id=  200
# 201  out of  40065 id=  201
# 202  out of  40065 id=  202
# 203  out of  40065 id=  203
# 204  out of  40065 id=  204
# 205  out of  40065 id=  205
# 206  out of  40065 id=  206
# 207  out of  40065 id=  207
# 208  out of  40065 id=  208
# 209  out of  40065 id=  209
# 210  out of  40065 id=  210
# 211  out of  40065 id=  211
# 212  out of  40065 id=  212
# 213  out of  40065 id=  213
# 214  out of  40065 id=  214
# 215  out of  40065 id=  215
# 216  out of  40065 id=  216
# 217  out of  40065 id=  217
# 218  out of  40065 id=  218
# 219  out of  40065 id=  219
# 220  out of  40065 id=  220
# 221  out of  40065 id=  221
# 222  out of  40065 id=  222
# 223  out of  40065 id=  223
# 224  out of  40065 id=  224
# 225  out of  40065 id=  225
# 226  out of  40065 id=  226
# 227  out of  40065 id=  227
# 228  out of  40065 id=  228
# 229  out of  40065 id=  229
# 230  out of  40065 id=  230
# 231  out of  40065 id=  231
# 232  out of  40065 id=  232
# 233  out of  40065 id=  233
# 234  out of  40065 id=  234
# 235  out of  40065 id=  235
# 236  out of  40065 id=  236
# 237  out of  40065 id=  237
# 238  out of  40065 id=  238
# 239  out of  40065 id=  239
# 240  out of  40065 id=  240
# 241  out of  40065 id=  241
# 242  out of  40065 id=  242
# 243  out of  40065 id=  243
# 244  out of  40065 id=  244
# 245  out of  40065 id=  245
# 246  out of  40065 id=  246
# 247  out of  40065 id=  247
# 248  out of  40065 id=  248
# 249  out of  40065 id=  249
# 250  out of  40065 id=  250
# 251  out of  40065 id=  251
# 252  out of  40065 id=  252
# 253  out of  40065 id=  253
# 254  out of  40065 id=  254
# 255  out of  40065 id=  255
# 256  out of  40065 id=  256
# 257  out of  40065 id=  257
# 258  out of  40065 id=  258
# 259  out of  40065 id=  259
# 260  out of  40065 id=  260
# 261  out of  40065 id=  261
# 262  out of  40065 id=  262
# 263  out of  40065 id=  263
# 264  out of  40065 id=  264
# 265  out of  40065 id=  265
# 266  out of  40065 id=  266
# 267  out of  40065 id=  267
# 268  out of  40065 id=  268
# 269  out of  40065 id=  269
# 270  out of  40065 id=  270
# 271  out of  40065 id=  271
# 272  out of  40065 id=  272
# 273  out of  40065 id=  273
# 274  out of  40065 id=  274
# 275  out of  40065 id=  275
# 276  out of  40065 id=  276
# 277  out of  40065 id=  277
# 278  out of  40065 id=  278
# 279  out of  40065 id=  279
# 280  out of  40065 id=  280
# 281  out of  40065 id=  281
# 282  out of  40065 id=  282
# 283  out of  40065 id=  283
# 284  out of  40065 id=  284
# 285  out of  40065 id=  285
# 286  out of  40065 id=  286
# 287  out of  40065 id=  287
# 288  out of  40065 id=  288
# 289  out of  40065 id=  289
# 290  out of  40065 id=  290
# 291  out of  40065 id=  291
# 292  out of  40065 id=  292
# 293  out of  40065 id=  293
# 294  out of  40065 id=  294
# 295  out of  40065 id=  295
# 296  out of  40065 id=  296
# 297  out of  40065 id=  297
# 298  out of  40065 id=  298
# 299  out of  40065 id=  299
# 300  out of  40065 id=  300
# 301  out of  40065 id=  301
# 302  out of  40065 id=  302
# 303  out of  40065 id=  303
# 304  out of  40065 id=  304
# 305  out of  40065 id=  305
# 306  out of  40065 id=  306
# 307  out of  40065 id=  307
# 308  out of  40065 id=  308
# 309  out of  40065 id=  309
# 310  out of  40065 id=  310
# 311  out of  40065 id=  311
# 312  out of  40065 id=  312
# 313  out of  40065 id=  313
# 314  out of  40065 id=  314
# 315  out of  40065 id=  315
# 316  out of  40065 id=  316
# 317  out of  40065 id=  317
# 318  out of  40065 id=  318
# 319  out of  40065 id=  319
# 320  out of  40065 id=  320
# 321  out of  40065 id=  321
# 322  out of  40065 id=  322
# 323  out of  40065 id=  323
# 324  out of  40065 id=  324
# 325  out of  40065 id=  325
# 326  out of  40065 id=  326
# 327  out of  40065 id=  327
# 328  out of  40065 id=  328
# 329  out of  40065 id=  329
# 330  out of  40065 id=  330
# 331  out of  40065 id=  331
# 332  out of  40065 id=  332
# 333  out of  40065 id=  333
# 334  out of  40065 id=  334
# 335  out of  40065 id=  335
# 336  out of  40065 id=  336
# 337  out of  40065 id=  337
# 338  out of  40065 id=  338
# 339  out of  40065 id=  339
# 340  out of  40065 id=  340
# 341  out of  40065 id=  341
# 342  out of  40065 id=  342
# 343  out of  40065 id=  343
# 344  out of  40065 id=  344
# 345  out of  40065 id=  345
# 346  out of  40065 id=  346
# 347  out of  40065 id=  347
# 348  out of  40065 id=  348
# 349  out of  40065 id=  349
# 350  out of  40065 id=  350
# 351  out of  40065 id=  351
# 352  out of  40065 id=  352
# 353  out of  40065 id=  353
# 354  out of  40065 id=  354
# 355  out of  40065 id=  355
# 356  out of  40065 id=  356
# 357  out of  40065 id=  357
# 358  out of  40065 id=  358
# 359  out of  40065 id=  359
# 360  out of  40065 id=  360
# 361  out of  40065 id=  361
# 362  out of  40065 id=  362
# 363  out of  40065 id=  363
# 364  out of  40065 id=  364
# 365  out of  40065 id=  365
# 366  out of  40065 id=  366
# 367  out of  40065 id=  367
# 368  out of  40065 id=  368
# 369  out of  40065 id=  369
# 370  out of  40065 id=  370
# 371  out of  40065 id=  371
# 372  out of  40065 id=  372
# 373  out of  40065 id=  373
# 374  out of  40065 id=  374
# 375  out of  40065 id=  375
# 376  out of  40065 id=  376
# 377  out of  40065 id=  377
# 378  out of  40065 id=  378
# 379  out of  40065 id=  379
# 380  out of  40065 id=  380
# 381  out of  40065 id=  381
# 382  out of  40065 id=  382
# 383  out of  40065 id=  383
# 384  out of  40065 id=  384
# 385  out of  40065 id=  385
# 386  out of  40065 id=  386
# 387  out of  40065 id=  387
# 388  out of  40065 id=  388
# 389  out of  40065 id=  389
# 390  out of  40065 id=  390
# 391  out of  40065 id=  391
# 392  out of  40065 id=  392
# 393  out of  40065 id=  393
# 394  out of  40065 id=  394
# 395  out of  40065 id=  395
# 396  out of  40065 id=  396
# 397  out of  40065 id=  397
# 398  out of  40065 id=  398
# 399  out of  40065 id=  399
# 400  out of  40065 id=  400
# 401  out of  40065 id=  401
# 402  out of  40065 id=  402
# 403  out of  40065 id=  403
# 404  out of  40065 id=  404
# 405  out of  40065 id=  405
# 406  out of  40065 id=  406
# 407  out of  40065 id=  407
# 408  out of  40065 id=  408
# 409  out of  40065 id=  409
# 410  out of  40065 id=  410
# 411  out of  40065 id=  411
# 412  out of  40065 id=  412
# 413  out of  40065 id=  413
# 414  out of  40065 id=  414
# 415  out of  40065 id=  415
# 416  out of  40065 id=  416
# 417  out of  40065 id=  417
# 418  out of  40065 id=  418
# 419  out of  40065 id=  419
# 420  out of  40065 id=  420
# 421  out of  40065 id=  421
# 422  out of  40065 id=  422
# 423  out of  40065 id=  423
# 424  out of  40065 id=  424
# 425  out of  40065 id=  425
# 426  out of  40065 id=  426
# 427  out of  40065 id=  427
# 428  out of  40065 id=  428
# 429  out of  40065 id=  429
# 430  out of  40065 id=  430
# 431  out of  40065 id=  431
# 432  out of  40065 id=  432
# 433  out of  40065 id=  433
# 434  out of  40065 id=  434
# 435  out of  40065 id=  435
# 436  out of  40065 id=  436
# 437  out of  40065 id=  437
# 438  out of  40065 id=  438
# 439  out of  40065 id=  439
# 440  out of  40065 id=  440
# 441  out of  40065 id=  441
# 442  out of  40065 id=  442
# 443  out of  40065 id=  443
# 444  out of  40065 id=  444
# 445  out of  40065 id=  445
# 446  out of  40065 id=  446
# 447  out of  40065 id=  447
# 448  out of  40065 id=  448
# 449  out of  40065 id=  449
# 450  out of  40065 id=  450
# 451  out of  40065 id=  451
# 452  out of  40065 id=  452
# 453  out of  40065 id=  453
# 454  out of  40065 id=  454
# 455  out of  40065 id=  455
# 456  out of  40065 id=  456
# 457  out of  40065 id=  457
# 458  out of  40065 id=  458
# 459  out of  40065 id=  459
# 460  out of  40065 id=  460
# 461  out of  40065 id=  461
# 462  out of  40065 id=  462
# 463  out of  40065 id=  463
# 464  out of  40065 id=  464
# 465  out of  40065 id=  465
# 466  out of  40065 id=  466
# 467  out of  40065 id=  467
# 468  out of  40065 id=  468
# 469  out of  40065 id=  469
# 470  out of  40065 id=  470
# 471  out of  40065 id=  471
# 472  out of  40065 id=  472
# 473  out of  40065 id=  473
# 474  out of  40065 id=  474
# 475  out of  40065 id=  475
# 476  out of  40065 id=  476
# 477  out of  40065 id=  477
# 478  out of  40065 id=  478
# 479  out of  40065 id=  479
# 480  out of  40065 id=  480
# 481  out of  40065 id=  481
# 482  out of  40065 id=  482
# 483  out of  40065 id=  483
# 484  out of  40065 id=  484
# 485  out of  40065 id=  485
# 486  out of  40065 id=  486
# 487  out of  40065 id=  487
# 488  out of  40065 id=  488
# 489  out of  40065 id=  489
# 490  out of  40065 id=  490
# 491  out of  40065 id=  491
# 492  out of  40065 id=  492
# 493  out of  40065 id=  493
# 494  out of  40065 id=  494
# 495  out of  40065 id=  495
# 496  out of  40065 id=  496
# 497  out of  40065 id=  497
# 498  out of  40065 id=  498
# 499  out of  40065 id=  499
# 500  out of  40065 id=  500
# 501  out of  40065 id=  501
# 502  out of  40065 id=  502
# 503  out of  40065 id=  503
# 504  out of  40065 id=  504
# 505  out of  40065 id=  505
# 506  out of  40065 id=  506
# 507  out of  40065 id=  507
# 508  out of  40065 id=  508
# 509  out of  40065 id=  509
# 510  out of  40065 id=  510
# 511  out of  40065 id=  511
# 512  out of  40065 id=  512
# 513  out of  40065 id=  513
# 514  out of  40065 id=  514
# 515  out of  40065 id=  515
# 516  out of  40065 id=  516
# 517  out of  40065 id=  517
# 518  out of  40065 id=  518
# 519  out of  40065 id=  519
# 520  out of  40065 id=  520
# 521  out of  40065 id=  521
# 522  out of  40065 id=  522
# 523  out of  40065 id=  523
# 524  out of  40065 id=  524
# 525  out of  40065 id=  525
# 526  out of  40065 id=  526
# 527  out of  40065 id=  527
# 528  out of  40065 id=  528
# 529  out of  40065 id=  529
# 530  out of  40065 id=  530
# 531  out of  40065 id=  531
# 532  out of  40065 id=  532
# 533  out of  40065 id=  533
# 534  out of  40065 id=  534
# 535  out of  40065 id=  535
# 536  out of  40065 id=  536
# 537  out of  40065 id=  537
# 538  out of  40065 id=  538
# 539  out of  40065 id=  539
# 540  out of  40065 id=  540
# 541  out of  40065 id=  541
# 542  out of  40065 id=  542
# 543  out of  40065 id=  543
# 544  out of  40065 id=  544
# 545  out of  40065 id=  545
# 546  out of  40065 id=  546
# 547  out of  40065 id=  547
# 548  out of  40065 id=  548
# 549  out of  40065 id=  549
# 550  out of  40065 id=  550
# 551  out of  40065 id=  551
# 552  out of  40065 id=  552
# 553  out of  40065 id=  553
# 554  out of  40065 id=  554
# 555  out of  40065 id=  555
# 556  out of  40065 id=  556
# 557  out of  40065 id=  557
# 558  out of  40065 id=  558
# 559  out of  40065 id=  559
# 560  out of  40065 id=  560
# 561  out of  40065 id=  561
# 562  out of  40065 id=  562
# 563  out of  40065 id=  563
# 564  out of  40065 id=  564
# 565  out of  40065 id=  565
# 566  out of  40065 id=  566
# 567  out of  40065 id=  567
# 568  out of  40065 id=  568
# 569  out of  40065 id=  569
# 570  out of  40065 id=  570
# 571  out of  40065 id=  571
# 572  out of  40065 id=  572
# 573  out of  40065 id=  573
# 574  out of  40065 id=  574
# 575  out of  40065 id=  575
# 576  out of  40065 id=  576
# 577  out of  40065 id=  577
# 578  out of  40065 id=  578
# 579  out of  40065 id=  579
# 580  out of  40065 id=  580
# 581  out of  40065 id=  581
# 582  out of  40065 id=  582
# 583  out of  40065 id=  583
# 584  out of  40065 id=  584
# 585  out of  40065 id=  585
# 586  out of  40065 id=  586
# 587  out of  40065 id=  587
# 588  out of  40065 id=  588
# 589  out of  40065 id=  589
# 590  out of  40065 id=  590
# 591  out of  40065 id=  591
# 592  out of  40065 id=  592
# 593  out of  40065 id=  593
# 594  out of  40065 id=  594
# 595  out of  40065 id=  595
# 596  out of  40065 id=  596
# 597  out of  40065 id=  597
# 598  out of  40065 id=  598
# 599  out of  40065 id=  599
# 600  out of  40065 id=  600
# 601  out of  40065 id=  601
# 602  out of  40065 id=  602
# 603  out of  40065 id=  603
# 604  out of  40065 id=  604
# 605  out of  40065 id=  605
# 606  out of  40065 id=  606
# 607  out of  40065 id=  607
# 608  out of  40065 id=  608
# 609  out of  40065 id=  609
# 610  out of  40065 id=  610
# 611  out of  40065 id=  611
# 612  out of  40065 id=  612
# 613  out of  40065 id=  613
# 614  out of  40065 id=  614
# 615  out of  40065 id=  615
# 616  out of  40065 id=  616
# 617  out of  40065 id=  617
# 618  out of  40065 id=  618
# 619  out of  40065 id=  619
# 620  out of  40065 id=  620
# 621  out of  40065 id=  621
# 622  out of  40065 id=  622
# 623  out of  40065 id=  623
# 624  out of  40065 id=  624
# 625  out of  40065 id=  625
# 626  out of  40065 id=  626
# 627  out of  40065 id=  627
# 628  out of  40065 id=  628
# 629  out of  40065 id=  629
# 630  out of  40065 id=  630
# 631  out of  40065 id=  631
# 632  out of  40065 id=  632
# 633  out of  40065 id=  633
# 634  out of  40065 id=  634
# 635  out of  40065 id=  635
# 636  out of  40065 id=  636
# 637  out of  40065 id=  637
# 638  out of  40065 id=  638
# 639  out of  40065 id=  639
# 640  out of  40065 id=  640
# 641  out of  40065 id=  641
# 642  out of  40065 id=  642
# 643  out of  40065 id=  643
# 644  out of  40065 id=  644
# 645  out of  40065 id=  645
# 646  out of  40065 id=  646
# 647  out of  40065 id=  647
# 648  out of  40065 id=  648
# 649  out of  40065 id=  649
# 650  out of  40065 id=  650
# 651  out of  40065 id=  651
# 652  out of  40065 id=  652
# 653  out of  40065 id=  653
# 654  out of  40065 id=  654
# 655  out of  40065 id=  655
# 656  out of  40065 id=  656
# 657  out of  40065 id=  657
# 658  out of  40065 id=  658
# 659  out of  40065 id=  659
# 660  out of  40065 id=  660
# 661  out of  40065 id=  661
# 662  out of  40065 id=  662
# 663  out of  40065 id=  663
# 664  out of  40065 id=  664
# 665  out of  40065 id=  665
# 666  out of  40065 id=  666
# 667  out of  40065 id=  667
# 668  out of  40065 id=  668
# 669  out of  40065 id=  669
# 670  out of  40065 id=  670
# 671  out of  40065 id=  671
# 672  out of  40065 id=  672
# 673  out of  40065 id=  673
# 674  out of  40065 id=  674
# 675  out of  40065 id=  675
# 676  out of  40065 id=  676
# 677  out of  40065 id=  677
# 678  out of  40065 id=  678
# 679  out of  40065 id=  679
# 680  out of  40065 id=  680
# 681  out of  40065 id=  681
# 682  out of  40065 id=  682
# 683  out of  40065 id=  683
# 684  out of  40065 id=  684
# 685  out of  40065 id=  685
# 686  out of  40065 id=  686
# 687  out of  40065 id=  687
# 688  out of  40065 id=  688
# 689  out of  40065 id=  689
# 690  out of  40065 id=  690
# 691  out of  40065 id=  691
# 692  out of  40065 id=  692
# 693  out of  40065 id=  693
# 694  out of  40065 id=  694
# 695  out of  40065 id=  695
# 696  out of  40065 id=  696
# 697  out of  40065 id=  697
# 698  out of  40065 id=  698
# 699  out of  40065 id=  699
# 700  out of  40065 id=  700
# 701  out of  40065 id=  701
# 702  out of  40065 id=  702
# 703  out of  40065 id=  703
# 704  out of  40065 id=  704
# 705  out of  40065 id=  705
# 706  out of  40065 id=  706
# 707  out of  40065 id=  707
# 708  out of  40065 id=  708
# 709  out of  40065 id=  709
# 710  out of  40065 id=  710
# 711  out of  40065 id=  711
# 712  out of  40065 id=  712
# 713  out of  40065 id=  713
# 714  out of  40065 id=  714
# 715  out of  40065 id=  715
# 716  out of  40065 id=  716
# 717  out of  40065 id=  717
# 718  out of  40065 id=  718
# 719  out of  40065 id=  719
# 720  out of  40065 id=  720
# 721  out of  40065 id=  721
# 722  out of  40065 id=  722
# 723  out of  40065 id=  723
# 724  out of  40065 id=  724
# 725  out of  40065 id=  725
# 726  out of  40065 id=  726
# 727  out of  40065 id=  727
# 728  out of  40065 id=  728
# 729  out of  40065 id=  729
# 730  out of  40065 id=  730
# 731  out of  40065 id=  731
# 732  out of  40065 id=  732
# 733  out of  40065 id=  733
# 734  out of  40065 id=  734
# 735  out of  40065 id=  735
# 736  out of  40065 id=  736
# 737  out of  40065 id=  737
# 738  out of  40065 id=  738
# 739  out of  40065 id=  739
# 740  out of  40065 id=  740
# 741  out of  40065 id=  741
# 742  out of  40065 id=  742
# 743  out of  40065 id=  743
# 744  out of  40065 id=  744
# 745  out of  40065 id=  745
# 746  out of  40065 id=  746
# 747  out of  40065 id=  747
# 748  out of  40065 id=  748
# 749  out of  40065 id=  749
# 750  out of  40065 id=  750
# 751  out of  40065 id=  751
# 752  out of  40065 id=  752
# 753  out of  40065 id=  753
# 754  out of  40065 id=  754
# 755  out of  40065 id=  755
# 756  out of  40065 id=  756
# 757  out of  40065 id=  757
# 758  out of  40065 id=  758
# 759  out of  40065 id=  759
# 760  out of  40065 id=  760
# 761  out of  40065 id=  761
# 762  out of  40065 id=  762
# 763  out of  40065 id=  763
# 764  out of  40065 id=  764
# 765  out of  40065 id=  765
# 766  out of  40065 id=  766
# 767  out of  40065 id=  767
# 768  out of  40065 id=  768
# 769  out of  40065 id=  769
# 770  out of  40065 id=  770
# 771  out of  40065 id=  771
# 772  out of  40065 id=  772
# 773  out of  40065 id=  773
# 774  out of  40065 id=  774
# 775  out of  40065 id=  775
# 776  out of  40065 id=  776
# 777  out of  40065 id=  777
# 778  out of  40065 id=  778
# 779  out of  40065 id=  779
# 780  out of  40065 id=  780
# 781  out of  40065 id=  781
# 782  out of  40065 id=  782
# 783  out of  40065 id=  783
# 784  out of  40065 id=  784
# 785  out of  40065 id=  785
# 786  out of  40065 id=  786
# 787  out of  40065 id=  787
# 788  out of  40065 id=  788
# 789  out of  40065 id=  789
# 790  out of  40065 id=  790
# 791  out of  40065 id=  791
# 792  out of  40065 id=  792
# 793  out of  40065 id=  793
# 794  out of  40065 id=  794
# 795  out of  40065 id=  795
# 796  out of  40065 id=  796
# 797  out of  40065 id=  797
# 798  out of  40065 id=  798
# 799  out of  40065 id=  799
# 800  out of  40065 id=  800
# 801  out of  40065 id=  801
# 802  out of  40065 id=  802
# 803  out of  40065 id=  803
# 804  out of  40065 id=  804
# 805  out of  40065 id=  805
# 806  out of  40065 id=  806
# 807  out of  40065 id=  807
# 808  out of  40065 id=  808
# 809  out of  40065 id=  809
# 810  out of  40065 id=  810
# 811  out of  40065 id=  811
# 812  out of  40065 id=  812
# 813  out of  40065 id=  813
# 814  out of  40065 id=  814
# 815  out of  40065 id=  815
# 816  out of  40065 id=  816
# 817  out of  40065 id=  817
# 818  out of  40065 id=  818
# 819  out of  40065 id=  819
# 820  out of  40065 id=  820
# 821  out of  40065 id=  821
# 822  out of  40065 id=  822
# 823  out of  40065 id=  823
# 824  out of  40065 id=  824
# 825  out of  40065 id=  825
# 826  out of  40065 id=  826
# 827  out of  40065 id=  827
# 828  out of  40065 id=  828
# 829  out of  40065 id=  829
# 830  out of  40065 id=  830
# 831  out of  40065 id=  831
# 832  out of  40065 id=  832
# 833  out of  40065 id=  833
# 834  out of  40065 id=  834
# 835  out of  40065 id=  835
# 836  out of  40065 id=  836
# 837  out of  40065 id=  837
# 838  out of  40065 id=  838
# 839  out of  40065 id=  839
# 840  out of  40065 id=  840
# 841  out of  40065 id=  841
# 842  out of  40065 id=  842
# 843  out of  40065 id=  843
# 844  out of  40065 id=  844
# 845  out of  40065 id=  845
# 846  out of  40065 id=  846
# 847  out of  40065 id=  847
# 848  out of  40065 id=  848
# 849  out of  40065 id=  849
# 850  out of  40065 id=  850
# 851  out of  40065 id=  851
# 852  out of  40065 id=  852
# 853  out of  40065 id=  853
# 854  out of  40065 id=  854
# 855  out of  40065 id=  855
# 856  out of  40065 id=  856
# 857  out of  40065 id=  857
# 858  out of  40065 id=  858
# 859  out of  40065 id=  859
# 860  out of  40065 id=  860
# 861  out of  40065 id=  861
# 862  out of  40065 id=  862
# 863  out of  40065 id=  863
# 864  out of  40065 id=  864
# 865  out of  40065 id=  865
# 866  out of  40065 id=  866
# 867  out of  40065 id=  867
# 868  out of  40065 id=  868
# 869  out of  40065 id=  869
# 870  out of  40065 id=  870
# 871  out of  40065 id=  871
# 872  out of  40065 id=  872
# 873  out of  40065 id=  873
# 874  out of  40065 id=  874
# 875  out of  40065 id=  875
# 876  out of  40065 id=  876
# 877  out of  40065 id=  877
# 878  out of  40065 id=  878
# 879  out of  40065 id=  879
# 880  out of  40065 id=  880
# 881  out of  40065 id=  881
# 882  out of  40065 id=  882
# 883  out of  40065 id=  883
# 884  out of  40065 id=  884
# 885  out of  40065 id=  885
# 886  out of  40065 id=  886
# 887  out of  40065 id=  887
# 888  out of  40065 id=  888
# 889  out of  40065 id=  889
# 890  out of  40065 id=  890
# 891  out of  40065 id=  891
# 892  out of  40065 id=  892
# 893  out of  40065 id=  893
# 894  out of  40065 id=  894
# 895  out of  40065 id=  895
# 896  out of  40065 id=  896
# 897  out of  40065 id=  897
# 898  out of  40065 id=  898
# 899  out of  40065 id=  899
# 900  out of  40065 id=  900
# 901  out of  40065 id=  901
# 902  out of  40065 id=  902
# 903  out of  40065 id=  903
# 904  out of  40065 id=  904
# 905  out of  40065 id=  905
# 906  out of  40065 id=  906
# 907  out of  40065 id=  907
# 908  out of  40065 id=  908
# 909  out of  40065 id=  909
# 910  out of  40065 id=  910
# 911  out of  40065 id=  911
# 912  out of  40065 id=  912
# 913  out of  40065 id=  913
# 914  out of  40065 id=  914
# 915  out of  40065 id=  915
# 916  out of  40065 id=  916
# 917  out of  40065 id=  917
# 918  out of  40065 id=  918
# 919  out of  40065 id=  919
# 920  out of  40065 id=  920
# 921  out of  40065 id=  921
# 922  out of  40065 id=  922
# 923  out of  40065 id=  923
# 924  out of  40065 id=  924
# 925  out of  40065 id=  925
# 926  out of  40065 id=  926
# 927  out of  40065 id=  927
# 928  out of  40065 id=  928
# 929  out of  40065 id=  929
# 930  out of  40065 id=  930
# 931  out of  40065 id=  931
# 932  out of  40065 id=  932
# 933  out of  40065 id=  933
# 934  out of  40065 id=  934
# 935  out of  40065 id=  935
# 936  out of  40065 id=  936
# 937  out of  40065 id=  937
# 938  out of  40065 id=  938
# 939  out of  40065 id=  939
# 940  out of  40065 id=  940
# 941  out of  40065 id=  941
# 942  out of  40065 id=  942
# 943  out of  40065 id=  943
# 944  out of  40065 id=  944
# 945  out of  40065 id=  945
# 946  out of  40065 id=  946
# 947  out of  40065 id=  947
# 948  out of  40065 id=  948
# 949  out of  40065 id=  949
# 950  out of  40065 id=  950
# 951  out of  40065 id=  951
# 952  out of  40065 id=  952
# 953  out of  40065 id=  953
# 954  out of  40065 id=  954
# 955  out of  40065 id=  955
# 956  out of  40065 id=  956
# 957  out of  40065 id=  957
# 958  out of  40065 id=  958
# 959  out of  40065 id=  959
# 960  out of  40065 id=  960
# 961  out of  40065 id=  961
# 962  out of  40065 id=  962
# 963  out of  40065 id=  963
# 964  out of  40065 id=  964
# 965  out of  40065 id=  965
# 966  out of  40065 id=  966
# 967  out of  40065 id=  967
# 968  out of  40065 id=  968
# 969  out of  40065 id=  969
# 970  out of  40065 id=  970
# 971  out of  40065 id=  971
# 972  out of  40065 id=  972
# 973  out of  40065 id=  973
# 974  out of  40065 id=  974
# 975  out of  40065 id=  975
# 976  out of  40065 id=  976
# 977  out of  40065 id=  977
# 978  out of  40065 id=  978
# 979  out of  40065 id=  979
# 980  out of  40065 id=  980
# 981  out of  40065 id=  981
# 982  out of  40065 id=  982
# 983  out of  40065 id=  983
# 984  out of  40065 id=  984
# 985  out of  40065 id=  985
# 986  out of  40065 id=  986
# 987  out of  40065 id=  987
# 988  out of  40065 id=  988
# 989  out of  40065 id=  989
# 990  out of  40065 id=  990
# 991  out of  40065 id=  991
# 992  out of  40065 id=  992
# 993  out of  40065 id=  993
# 994  out of  40065 id=  994
# 995  out of  40065 id=  995
# 996  out of  40065 id=  996
# 997  out of  40065 id=  997
# 998  out of  40065 id=  998
# 999  out of  40065 id=  999
# 1000  out of  40065 id=  1000
# 1001  out of  40065 id=  1001
# 1002  out of  40065 id=  1002
# 1003  out of  40065 id=  1003
# 1004  out of  40065 id=  1004
# 1005  out of  40065 id=  1005
# 1006  out of  40065 id=  1006
# 1007  out of  40065 id=  1007
# 1008  out of  40065 id=  1008
# 1009  out of  40065 id=  1009
# 1010  out of  40065 id=  1010
# 1011  out of  40065 id=  1011
# 1012  out of  40065 id=  1012
# 1013  out of  40065 id=  1013
# 1014  out of  40065 id=  1014
# 1015  out of  40065 id=  1015
# 1016  out of  40065 id=  1016
# 1017  out of  40065 id=  1017
# 1018  out of  40065 id=  1018
# 1019  out of  40065 id=  1019
# 1020  out of  40065 id=  1020
# 1021  out of  40065 id=  1021
# 1022  out of  40065 id=  1022
# 1023  out of  40065 id=  1023
# 1024  out of  40065 id=  1024
# 1025  out of  40065 id=  1025
# 1026  out of  40065 id=  1026
# 1027  out of  40065 id=  1027
# 1028  out of  40065 id=  1028
# 1029  out of  40065 id=  1029
# 1030  out of  40065 id=  1030
# 1031  out of  40065 id=  1031
# 1032  out of  40065 id=  1032
# 1033  out of  40065 id=  1033
# 1034  out of  40065 id=  1034
# 1035  out of  40065 id=  1035
# 1036  out of  40065 id=  1036
# 1037  out of  40065 id=  1037
# 1038  out of  40065 id=  1038
# 1039  out of  40065 id=  1039
# 1040  out of  40065 id=  1040
# 1041  out of  40065 id=  1041
# 1042  out of  40065 id=  1042
# 1043  out of  40065 id=  1043
# 1044  out of  40065 id=  1044
# 1045  out of  40065 id=  1045
# 1046  out of  40065 id=  1046
# 1047  out of  40065 id=  1047
# 1048  out of  40065 id=  1048
# 1049  out of  40065 id=  1049
# 1050  out of  40065 id=  1050
# 1051  out of  40065 id=  1051
# 1052  out of  40065 id=  1052
# 1053  out of  40065 id=  1053
# 1054  out of  40065 id=  1054
# 1055  out of  40065 id=  1055
# 1056  out of  40065 id=  1056
# 1057  out of  40065 id=  1057
# 1058  out of  40065 id=  1058
# 1059  out of  40065 id=  1059
# 1060  out of  40065 id=  1060
# 1061  out of  40065 id=  1061
# 1062  out of  40065 id=  1062
# 1063  out of  40065 id=  1063
# 1064  out of  40065 id=  1064
# 1065  out of  40065 id=  1065
# 1066  out of  40065 id=  1066
# 1067  out of  40065 id=  1067
# 1068  out of  40065 id=  1068
# 1069  out of  40065 id=  1069
# 1070  out of  40065 id=  1070
# 1071  out of  40065 id=  1071
# 1072  out of  40065 id=  1072
# 1073  out of  40065 id=  1073
# 1074  out of  40065 id=  1074
# 1075  out of  40065 id=  1075
# 1076  out of  40065 id=  1076
# 1077  out of  40065 id=  1077
# 1078  out of  40065 id=  1078
# 1079  out of  40065 id=  1079
# 1080  out of  40065 id=  1080
# 1081  out of  40065 id=  1081
# 1082  out of  40065 id=  1082
# 1083  out of  40065 id=  1083
# 1084  out of  40065 id=  1084
# 1085  out of  40065 id=  1085
# 1086  out of  40065 id=  1086
# 1087  out of  40065 id=  1087
# 1088  out of  40065 id=  1088
# 1089  out of  40065 id=  1089
# 1090  out of  40065 id=  1090
# 1091  out of  40065 id=  1091
# 1092  out of  40065 id=  1092
# 1093  out of  40065 id=  1093
# 1094  out of  40065 id=  1094
# 1095  out of  40065 id=  1095
# 1096  out of  40065 id=  1096
# 1097  out of  40065 id=  1097
# 1098  out of  40065 id=  1098
# 1099  out of  40065 id=  1099
# 1100  out of  40065 id=  1100
# 1101  out of  40065 id=  1101
# 1102  out of  40065 id=  1102
# 1103  out of  40065 id=  1103
# 1104  out of  40065 id=  1104
# 1105  out of  40065 id=  1105
# 1106  out of  40065 id=  1106
# 1107  out of  40065 id=  1107
# 1108  out of  40065 id=  1108
# 1109  out of  40065 id=  1109
# 1110  out of  40065 id=  1110

# %%
with open(img_path, 'rb') as image_h:
    image_h.seek(0)
    sector = image_h.read(512)
    print(sector)
# Out:
# b'EVF\t\r\n\xff\x00\x01\x01\x00\x00\x00header2x\x01u\x8ek\x0e\x820\x10\x84\xe7/\xbd\x8bI\xc1G\xf4\x0e^\xa2\x02Q\x12\xc1\x17\x18O\xaf~\xbb\x98\xc8\x1f\xb2\x99\xe9d\xdb\xce\xcc\xe7\xbdTP\xab\xa4F\x1d*)S\t:P\x83\x1e\xb4\xaa\xe0\x87\xef\x92\x9e\xe8\x8bs\x8b\x1a\xc0\x15T\xfc\n\x9c\xd3)\x14\x95\x83\xa8\x82\xd9p\xb7\xf7\x94A/t\xcen\xa7\x95\xb6\xce\xb9\xd6\xcc\xdc6\xc3;\xd0\xe0NJ\x8d\x8a\xfe2x\xb25m\xbca\xed\xadz\x1d\xd8\x9c\xe9h\xcd\x8c\x93N\xf0\xd1\xbb&\xdd~\xff#\xe7\xbf\xed\x82>\x99F\xb6\xed\x987\xe05\x97\xd6\xb9_\xe9\t\xe6=\xbe\x9b\xba\x9a\xa3\xf9|\x01&\xec&\xf6header2q\x19x\x01u\x8ek\x0e\x820\x10\x84\xe7/\xbd\x8bI\xc1G\xf4\x0e^\xa2\x02Q\x12\xc1\x17\x18O\xaf~\xbb\x98\xc8\x1f\xb2\x99\xe9d\xdb\xce\xcc\xe7\xbdTP\xab\xa4F\x1d*)S\t:P\x83\x1e\xb4\xaa\xe0\x87\xef\x92\x9e\xe8\x8bs\x8b\x1a\xc0\x15T\xfc\n\x9c\xd3)\x14\x95\x83\xa8\x82\xd9p\xb7\xf7\x94A/t\xcen\xa7\x95\xb6\xce\xb9\xd6\xcc\xdc6\xc3;\xd0\xe0NJ\x8d\x8a\xfe2x\xb25m\xbca\xed\xadz\x1d\xd8\x9c\xe9h\xcd\x8c\x93N\xf0\xd1\xbb&\xdd~\xff#\xe7\xbf\xed\x82>\x99F\xb6\xed\x987\xe05\x97\xd6\xb9_\xe9\t\xe6=\xbe\x9b\xba\x9a\xa3\xf9|\x01&\xec&\xf6header\x00'
